# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Path of the file to read
fifa_filepath = "C:\\Users\\91865\\Downloads\\fifa.csv"

# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

fifa_data
# Out:
#              ARG  BRA   ESP   FRA  GER   ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0   2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0   2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0   3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0   1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0   2.0
# ...          ...  ...   ...   ...  ...   ...
# 2018-02-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-03-15   4.0  2.0   6.0   9.0  1.0  14.0
# 2018-04-12   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-05-17   5.0  2.0   8.0   7.0  1.0  20.0
# 2018-06-07   5.0  2.0  10.0   7.0  1.0  19.0
#
# [286 rows x 6 columns]

# %%
# Set the width and height of the figure
plt.figure(figsize=(15,5))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)
#sns.barplot(data=fifa_data)
#sns.heatmap(data=fifa_data)

# %%
list(fifa_data.columns)
# Out:
# ['ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA']

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=fifa_data['BRA'], label="Brasil")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=fifa_data['GER'], label="Germany")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %%
sns.barplot(data=fifa_data)

# %%
plt.figure(figsize=(20,10))
# Heatmap showing average game score by platform and genre
sns.heatmap(fifa_data, annot=True)
# Add label for horizontal axis
plt.xlabel("Genre")
# Add label for vertical axis
plt.title("Average Game Score, by Platform and Genre")
# Out:
# Text(0.5, 1, 'Average Game Score, by Platform and Genre')

# %%
# ENDING FIFA DATA SET AND STARTING OUT MEDICAL INSURANCE
# Path of the file to read
insurance_filepath = "C:\\Users\\91865\\Downloads\\insurance.csv"

# Read the file into a variable fifa_data
insurance_data = pd.read_csv(insurance_filepath, index_col="age")

# %%
insurance_data
# Out:
#         sex     bmi  children smoker     region      charges
# age
# 19   female  27.900         0    yes  southwest  16884.92400
# 18     male  33.770         1     no  southeast   1725.55230
# 28     male  33.000         3     no  southeast   4449.46200
# 33     male  22.705         0     no  northwest  21984.47061
# 32     male  28.880         0     no  northwest   3866.85520
# ..      ...     ...       ...    ...        ...          ...
# 50     male  30.970         3     no  northwest  10600.54830
# 18   female  31.920         0     no  northeast   2205.98080
# 18   female  36.850         0     no  southeast   1629.83350
# 21   female  25.800         0     no  southwest   2007.94500
# 61   female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 6 columns]

# %%
plt.figure(figsize=(18, 6))
# Bar chart showing average score for racing games by platform
sns.barplot(x=insurance_data.index, y=insurance_data['children'])
# Add label for horizontal axis
plt.xlabel("")
# Add label for vertical axis
plt.title("parents at what age")
# Out:
# Text(0.5, 1.0, 'parents at what age')

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], color = 'red')

# %%
sns.regplot(x=insurance_data['bmi'], y=insurance_data['charges'], color = 'black')

# %%
sns.scatterplot(x=insurance_data['bmi'], y=insurance_data['charges'], hue=insurance_data['smoker'],)

# %%
sns.lmplot(x="bmi", y="charges", hue="smoker", data=insurance_data, )

# %%
sns.swarmplot(x=insurance_data['smoker'],
              y=insurance_data['charges'])

# %%
sns.distplot(a=insurance_data['charges'], kde=False)

# %%
sns.kdeplot(data=insurance_data['charges'], shade=True)

# %%
sns.jointplot(x=insurance_data['charges'], y=insurance_data['bmi'], kind="kde")
